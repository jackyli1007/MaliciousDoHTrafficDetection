# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import random
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc, classification_report  #混淆矩阵
from sklearn import metrics

from sklearn import metrics
import seaborn as sns

from sklearn.preprocessing import StandardScaler

import dgl.nn as dglnn
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import dgl
import torch



#mpl.rcParams['font.sans-serif'] = ['FangSong']SimHei
# plt.rcParams['font.sans-serif'] = ['FangSong']	# 显示中文
# plt.rcParams['axes.unicode_minus'] = False		# 显示负号

# 创建预测图目录
import os  
# 获取当前工作目录  
# 判断imgs文件夹是否存在 保存结果图片 
imgs_path = './model'
if not os.path.exists(imgs_path):  
    # 如果不存在，则创建imgs文件夹  
    os.makedirs(imgs_path)  
    
# 设置随机种子为固定值，这里设为0
torch.manual_seed(42)

# %% [markdown]
# 图的边的特征列名

# %%
edge_f = ['Duration', 'FlowBytesSent', 'FlowSentRate',
       'FlowBytesReceived', 'FlowReceivedRate', 'PacketLengthVariance',
       'PacketLengthStandardDeviation', 'PacketLengthMean',
       'PacketLengthMedian', 'PacketLengthMode', 'PacketLengthSkewFromMedian',
       'PacketLengthSkewFromMode', 'PacketLengthCoefficientofVariation',
       'PacketTimeVariance', 'PacketTimeStandardDeviation', 'PacketTimeMean',
       'PacketTimeMedian', 'PacketTimeMode', 'PacketTimeSkewFromMedian',
       'PacketTimeSkewFromMode', 'PacketTimeCoefficientofVariation',
       'ResponseTimeTimeVariance', 'ResponseTimeTimeStandardDeviation',
       'ResponseTimeTimeMean', 'ResponseTimeTimeMedian',
       'ResponseTimeTimeMode', 'ResponseTimeTimeSkewFromMedian',
       'ResponseTimeTimeSkewFromMode',
       'ResponseTimeTimeCoefficientofVariation']

# %% [markdown]
# 读取两种数据

# %%
benign = pd.read_csv('l2-benign.csv')

# %%
malicious = pd.read_csv('l2-malicious.csv')

# %% [markdown]
# 标签标注：良性：0  恶性：1

# %%
benign['Label'] = 0
malicious['Label'] = 1

# %% [markdown]
# 数据合并 去除空值  随机筛选2万条数据进行训练和测试

# %%
df = pd.concat([benign,malicious]).dropna()

# %% [markdown]
# 设置随机抽取数据集数量

# %%
sample = 3000

# %%
# 筛选标签为0的数据  
df_label_0 = df[df['Label'] == 0]   
# 筛选标签为1的数据  
df_label_1 = df[df['Label'] == 1]  
# 从标签为0的数据中随机取sample条  
sample_0 = df_label_0.sample(n=sample, random_state=42)  # 设置random_state以确保结果的可复现性  
# 从标签为1的数据中随机取sample条  
sample_1 = df_label_1.sample(n=sample, random_state=42)  
# 合并样本作为训练集  
data = pd.concat([sample_0, sample_1])  
# 如果需要，保存训练集到CSV文件  
data.to_csv(f'train_set_{sample}.csv', index=False)

# %%
data.shape
# Out:
# (6000, 35)

# %%
data.head()
# Out:
#              SourceIP    DestinationIP  SourcePort  DestinationPort  \
# 8512   192.168.20.111          8.8.8.8       47458              443
# 13762  192.168.20.111          9.9.9.9       40246              443
# 10124  192.168.20.111          8.8.8.8       49038              443
# 2635   192.168.20.111          8.8.8.8       37502              443
# 16230  192.168.20.113  176.103.130.130       41924              443
#
#               TimeStamp    Duration  FlowBytesSent  FlowSentRate  \
# 8512   2019/12/16 19:32    0.195289           4468  22878.912790
# 13762  2019/12/19 23:34    0.125645           2351  18711.448920
# 10124   2019/12/10 1:28  118.016134            513      4.346863
# 2635   2019/12/13 18:05    0.015491            171  11038.667610
# 16230  2019/12/19 19:36    0.021905            128   5843.414745
#
#        FlowBytesReceived  FlowReceivedRate  ...  \
# 8512                6084      31153.828430  ...
# 13762               4472      35592.343510  ...
# 10124                381          3.228372  ...
# 2635                 105       6778.129236  ...
# 16230                 74       3378.224150  ...
#
#        PacketTimeCoefficientofVariation  ResponseTimeTimeVariance  \
# 8512                           0.417545              7.260540e-05
# 13762                          0.518810              6.056590e-05
# 10124                          0.922606              3.070000e-10
# 2635                           0.707107              0.000000e+00
# 16230                          0.707107              0.000000e+00
#
#        ResponseTimeTimeStandardDeviation  ResponseTimeTimeMean  \
# 8512                            0.008521              0.009222
# 13762                           0.007782              0.007827
# 10124                           0.000018              0.015483
# 2635                            0.000000              0.015477
# 16230                           0.000000              0.021895
#
#        ResponseTimeTimeMedian  ResponseTimeTimeMode  \
# 8512                 0.008136              0.000039
# 13762                0.007811              0.015544
# 10124                0.015473              0.015469
# 2635                 0.015477              0.015477
# 16230                0.021895              0.021895
#
#        ResponseTimeTimeSkewFromMedian  ResponseTimeTimeSkewFromMode  \
# 8512                         0.382191                      1.077651
# 13762                        0.005879                     -0.991627
# 10124                        1.769584                      0.818195
# 2635                       -10.000000                    -10.000000
# 16230                      -10.000000                    -10.000000
#
#        ResponseTimeTimeCoefficientofVariation  Label
# 8512                                 0.924020      0
# 13762                                0.994335      0
# 10124                                0.001131      0
# 2635                                 0.000000      0
# 16230                                0.000000      0
#
# [5 rows x 35 columns]

# %%
data.isna().sum()
# Out:
# SourceIP                                  0
# DestinationIP                             0
# SourcePort                                0
# DestinationPort                           0
# TimeStamp                                 0
# Duration                                  0
# FlowBytesSent                             0
# FlowSentRate                              0
# FlowBytesReceived                         0
# FlowReceivedRate                          0
# PacketLengthVariance                      0
# PacketLengthStandardDeviation             0
# PacketLengthMean                          0
# PacketLengthMedian                        0
# PacketLengthMode                          0
# PacketLengthSkewFromMedian                0
# PacketLengthSkewFromMode                  0
# PacketLengthCoefficientofVariation        0
# PacketTimeVariance                        0
# PacketTimeStandardDeviation               0
# PacketTimeMean                            0
# PacketTimeMedian                          0
# PacketTimeMode                            0
# PacketTimeSkewFromMedian                  0
# PacketTimeSkewFromMode                    0
# PacketTimeCoefficientofVariation          0
# ResponseTimeTimeVariance                  0
# ResponseTimeTimeStandardDeviation         0
# ResponseTimeTimeMean                      0
# ResponseTimeTimeMedian                    0
# ResponseTimeTimeMode                      0
# ResponseTimeTimeSkewFromMedian            0
# ResponseTimeTimeSkewFromMode              0
# ResponseTimeTimeCoefficientofVariation    0
# Label                                     0
# dtype: int64

# %%
pd.set_option('display.float_format',lambda x:'{:.3f}'.format(x))    #控制输出为精确到小数点后三位
color = sns.color_palette()
sns.set_style('darkgrid')

# %% [markdown]
# 目标和特征热力图

# %%
corrmat = data.corr()
f,ax = plt.subplots(figsize=(20,20))
ax.set_xticklabels(corrmat,rotation='horizontal')
sns.heatmap(corrmat, vmax =0.9,square=True)
label_y = ax.get_yticklabels()
plt.setp(label_y , rotation = 360)
label_x = ax.get_xticklabels()
plt.setp(label_x , rotation = 90)
plt.show();
# Out:
# C:\Users\tojoy\AppData\Local\Temp\ipykernel_43556\1090798881.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = data.corr()
# C:\Users\tojoy\AppData\Local\Temp\ipykernel_43556\1090798881.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(corrmat,rotation='horizontal')

# %% [markdown]
# 边特征标准化 消除量纲影响

# %%
scaler = StandardScaler()
scaler.fit(data[edge_f])
data[edge_f] = scaler.transform(data[edge_f])

# %% [markdown]
# 生成节点字符串

# %%
data['src'] = data['SourceIP']+ '.'+data['SourcePort'].astype(str)

# %%
data['dst'] = data['DestinationIP']+ '.'+data['DestinationPort'].astype(str)

# %% [markdown]
# 合并所有发送和接收节点

# %%
nodes = list(set(data['src'].tolist() + data['dst'].tolist()))

# %%
nodes[-10:]
# Out:
# ['192.168.20.111.45132',
#  '192.168.20.144.36074',
#  '192.168.20.206.57134',
#  '192.168.20.113.60676',
#  '192.168.20.207.50572',
#  '192.168.20.113.37188',
#  '192.168.20.191.64879',
#  '192.168.20.111.51684',
#  '192.168.20.111.52532',
#  '192.168.20.204.43522']

# %% [markdown]
# 节点特征：使用IP和PORT作为节点特征值

# %%
nodes_df = pd.DataFrame(nodes,columns=['node'])

# %%
nodes_df_split = nodes_df['node'].str.split('.', expand=True)

# %%
node_feature = pd.concat([nodes_df,nodes_df_split],axis=1)

# %%
node_feature['id'] = node_feature.index

# %%
node_feature.head()
# Out:
#                    node    0    1   2    3      4  id
# 0  192.168.20.113.56414  192  168  20  113  56414   0
# 1  192.168.20.207.37784  192  168  20  207  37784   1
# 2  192.168.20.144.59468  192  168  20  144  59468   2
# 3  192.168.20.206.47166  192  168  20  206  47166   3
# 4  192.168.20.113.39510  192  168  20  113  39510   4

# %% [markdown]
# 节点特征标准化

# %%
scaler1 = StandardScaler()
scaler1.fit(node_feature[[0,1,2,3,4]])  # data为待标准化的数据
node_feature[[0,1,2,3,4]] = scaler1.transform(node_feature[[0,1,2,3,4]])

# %% [markdown]
# 边的数量

# %%
len(data[['src','dst']].drop_duplicates())
# Out:
# 5437

# %% [markdown]
# 补齐节点序号，以便输入模型处理

# %%
data = data.drop_duplicates(subset=['src','dst'])

# %%
data = pd.merge(data,node_feature[['node','id']],left_on='src',right_on='node')

# %%
data = pd.merge(data,node_feature[['node','id']],left_on='dst',right_on='node')

# %%
data[data['FlowBytesSent']==0]
# Out:
# Empty DataFrame
# Columns: [SourceIP, DestinationIP, SourcePort, DestinationPort, TimeStamp, Duration, FlowBytesSent, FlowSentRate, FlowBytesReceived, FlowReceivedRate, PacketLengthVariance, PacketLengthStandardDeviation, PacketLengthMean, PacketLengthMedian, PacketLengthMode, PacketLengthSkewFromMedian, PacketLengthSkewFromMode, PacketLengthCoefficientofVariation, PacketTimeVariance, PacketTimeStandardDeviation, PacketTimeMean, PacketTimeMedian, PacketTimeMode, PacketTimeSkewFromMedian, PacketTimeSkewFromMode, PacketTimeCoefficientofVariation, ResponseTimeTimeVariance, ResponseTimeTimeStandardDeviation, ResponseTimeTimeMean, ResponseTimeTimeMedian, ResponseTimeTimeMode, ResponseTimeTimeSkewFromMedian, ResponseTimeTimeSkewFromMode, ResponseTimeTimeCoefficientofVariation, Label, src, dst, node_x, id_x, node_y, id_y]
# Index: []
#
# [0 rows x 41 columns]

# %% [markdown]
# 构建图网络模型

# %%
src = data['id_x'].values
dst = data['id_y'].values

# %%
src = torch.tensor(src,dtype=torch.long)
dst = torch.tensor(dst,dtype=torch.long)

# %%
edge_pred_graph = dgl.graph((src, dst))

# %%
# 建立点和边特征，以及边的标签
edge_pred_graph.ndata['feature'] = torch.tensor(node_feature[[0,1,2,3,4]].values,dtype=torch.float)
edge_pred_graph.edata['feature'] = torch.tensor(data[edge_f].values,dtype=torch.float)
edge_pred_graph.edata['label'] = torch.tensor(data['Label'].values)
# 进行训练、验证和测试集划分
edge_pred_graph.edata['train_mask'] = torch.zeros(len(src), dtype=torch.bool).bernoulli(0.8)

# %%
node_feats = torch.tensor(node_feature[[0,1,2,3,4]].values,dtype=torch.float)
edge_feats = torch.tensor(data[edge_f].values,dtype=torch.float)
edge_labels = torch.tensor(data['Label'].values)
train_mask = torch.zeros(len(src), dtype=torch.bool).bernoulli(0.8)
test_mask = ~train_mask

# %%
class SAGE(nn.Module):
    def __init__(self, in_feats, hid_feats, out_feats):
        super().__init__()
        # 实例化SAGEConve，in_feats是输入特征的维度，out_feats是输出特征的维度，aggregator_type是聚合函数的类型
        self.conv1 = dglnn.SAGEConv(in_feats=in_feats, out_feats=hid_feats, aggregator_type='mean')
        self.conv2 = dglnn.SAGEConv(in_feats=hid_feats, out_feats=out_feats, aggregator_type='mean')

    def forward(self, graph, inputs):
        # 输入是节点的特征
        h = self.conv1(graph, inputs)
        h = F.relu(h)
        h = self.conv2(graph, h)
        return h

# %%
import dgl.function as fn
class DotProductPredictor(nn.Module):
    def forward(self, graph, h):
        # h是从5.1节的GNN模型中计算出的节点表示
        with graph.local_scope():
            graph.ndata['h'] = h
            graph.apply_edges(fn.u_dot_v('h', 'h', 'score'))
            return graph.edata['score']

# %%
class MLPPredictor(nn.Module):
    def __init__(self, in_features, out_classes):
        super().__init__()
        self.W = nn.Linear(in_features * 3, out_classes)
        
    def apply_edges(self, edges):
        h_u = edges.src['h']
        h_v = edges.dst['h']
        e_f = edges.data['feature']
        #e_f = edges['feature']
        score = self.W(torch.cat([h_u, h_v, e_f], 1))
        return {'score': score}

    def forward(self, graph, h):
        # h是从5.1节的GNN模型中计算出的节点表示
        with graph.local_scope():
            graph.ndata['h'] = h
            graph.apply_edges(self.apply_edges)
            return graph.edata['score']

# %%
class Model(nn.Module):
    def __init__(self, in_features, hidden_features, out_features):
        super().__init__()
        self.sage = SAGE(in_features, hidden_features, out_features)
        #self.pred = DotProductPredictor()
        self.pred = MLPPredictor(5,2)
        self.S = nn.Softmax()
        
    def forward(self, g, x):
        h = self.sage(g, x)
        s = self.pred(g, h)
        return self.S(s)

# %%
class EdgeClassifier(nn.Module):
    def __init__(self, in_node_feats, in_edge_feats, hidden_size, out_size):
        super(EdgeClassifier, self).__init__()

        self.rel_graph_conv = RelGraphConv(hidden_size, hidden_size, num_rels=1)
        self.classifier = nn.Linear(hidden_size * 3, out_size)  # 考虑到节点和边的组合特征
        self.sage_n = SAGE(in_node_feats, hidden_size, hidden_size)
        #self.sage_e = SAGE(in_edge_feats, hidden_size, out_size)
        self.edge_embedding = nn.Linear(in_edge_feats, hidden_size)

    def forward(self, g, node_feats, edge_feats):
        self.node_embedding = self.sage_n(g,node_feats)
        #self.edge_embedding = self.sage_e(g,edge_feats)
        # 节点嵌入
        h_nodes = F.relu(self.node_embedding)

        # 边嵌入
        h_edges = F.relu(self.edge_embedding(edge_feats))

        # 使用DGL的RelGraphConv进行消息传递
        g.ndata['feature'] = h_nodes
        g.edata['feature'] = h_edges
        g.apply_edges(lambda edges: {'feature': torch.cat([edges.src['feature'], edges.dst['feature'], edges.data['feature']], dim=1)})
        h_edges = g.edata['feature']

        # 分类器
        #h_edges = F.relu(self.rel_graph_conv(g, h_edges))
        edge_preds = self.classifier(h_edges)

        return edge_preds

# %% [markdown]
# 定义交叉熵损失

# %%
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# 训练模型，输出损失值loss

# %%
from dgl.nn import RelGraphConv

# %%
class EarlyStopping():
    def __init__(self,patience=7,verbose=False,delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
    def __call__(self,val_loss,model,path):
        #print("val_loss={}".format(val_loss))
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss,model,path)
        elif score < self.best_score+self.delta:
            self.counter+=1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter>=self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss,model,path)
            self.counter = 0
    def save_checkpoint(self,val_loss,model,path):
        if self.verbose:
            print(
                f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), path+'/'+f'model_checkpoint_{sample}.pth')
        self.val_loss_min = val_loss

# %%
early_stopping = EarlyStopping(patience=10,verbose=False)

# %%
loss_list = []
val_loss_list = []

acc = []
val_acc = []

epoch = 1000
edge_label = edge_pred_graph.edata['label']
model = EdgeClassifier(5, 29, 64, 2)
opt = torch.optim.Adam(model.parameters())
for epoch in range(1,epoch+2):
    outputs = model(edge_pred_graph, node_feats, edge_feats)
    outputs_max = np.argmax(outputs[train_mask].detach().numpy(), axis=1)
    labels_max = edge_label[train_mask].detach().numpy()
    total_number = 0
    correct_number = 0
    for i in range(len(outputs_max)):
        if outputs_max[i] == labels_max[i]:
            correct_number += 1
        total_number += 1
    acc.append(correct_number/total_number)
    
    loss = criterion(outputs[train_mask], edge_label[train_mask])
    opt.zero_grad()
    loss.backward()
    opt.step()
    loss_list.append(loss.item())
    
    model.eval()
    val_outputs = model(edge_pred_graph, node_feats, edge_feats)
    val_outputs_max = np.argmax(val_outputs[test_mask].detach().numpy(), axis=1)
    val_labels_max = edge_label[test_mask].detach().numpy()
    val_total_number = 0
    val_correct_number = 0

    for i in range(len(val_outputs_max)):
        if val_outputs_max[i] == val_labels_max[i]:
            val_correct_number += 1
        val_total_number += 1
    val_acc.append(val_correct_number/val_total_number)
    val_loss = criterion(outputs[test_mask], edge_label[test_mask])
    val_loss_list.append(val_loss.item())
    
    if epoch % 10 == 0:

        print(f'Epoch {epoch} | Train Loss: {loss.item():.4f} Accuracy: {correct_number / total_number:.4f} | Val Loss: {val_loss.item():.4f} Accuracy: {val_correct_number / val_total_number:.4f}')
        
    #==================early stopping======================
    early_stopping(val_loss_list[-1],model=model,path=r'model')
    if early_stopping.early_stop:
        print("Early stopping")
        break
# Out:
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Epoch 10 | Train Loss: 0.7094 Accuracy: 0.5104 | Val Loss: 0.7168 Accuracy: 0.5122
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 20 | Train Loss: 0.5058 Accuracy: 0.7479 | Val Loss: 0.5109 Accuracy: 0.7846
# Epoch 30 | Train Loss: 0.4005 Accuracy: 0.8525 | Val Loss: 0.4073 Accuracy: 0.8498
# Epoch 40 | Train Loss: 0.3312 Accuracy: 0.8744 | Val Loss: 0.3322 Accuracy: 0.8796
# Epoch 50 | Train Loss: 0.2891 Accuracy: 0.8973 | Val Loss: 0.2900 Accuracy: 0.9050
# Epoch 60 | Train Loss: 0.2566 Accuracy: 0.8973 | Val Loss: 0.2563 Accuracy: 0.9095
# Epoch 70 | Train Loss: 0.2304 Accuracy: 0.9174 | Val Loss: 0.2299 Accuracy: 0.9267
# Epoch 80 | Train Loss: 0.2073 Accuracy: 0.9252 | Val Loss: 0.2056 Accuracy: 0.9321
# Epoch 90 | Train Loss: 0.1882 Accuracy: 0.9351 | Val Loss: 0.1862 Accuracy: 0.9376
# Epoch 100 | Train Loss: 0.1714 Accuracy: 0.9485 | Val Loss: 0.1693 Accuracy: 0.9466
# Epoch 110 | Train Loss: 0.1565 Accuracy: 0.9515 | Val Loss: 0.1545 Accuracy: 0.9520
# Epoch 120 | Train Loss: 0.1432 Accuracy: 0.9561 | Val Loss: 0.1415 Accuracy: 0.9620
# Epoch 130 | Train Loss: 0.1313 Accuracy: 0.9598 | Val Loss: 0.1300 Accuracy: 0.9638
# Epoch 140 | Train Loss: 0.1206 Accuracy: 0.9640 | Val Loss: 0.1198 Accuracy: 0.9692
# Epoch 150 | Train Loss: 0.1109 Accuracy: 0.9675 | Val Loss: 0.1106 Accuracy: 0.9738
# Epoch 160 | Train Loss: 0.1021 Accuracy: 0.9705 | Val Loss: 0.1021 Accuracy: 0.9738
# Epoch 170 | Train Loss: 0.0941 Accuracy: 0.9767 | Val Loss: 0.0945 Accuracy: 0.9774
# Epoch 180 | Train Loss: 0.0869 Accuracy: 0.9818 | Val Loss: 0.0875 Accuracy: 0.9810
# Epoch 190 | Train Loss: 0.0804 Accuracy: 0.9836 | Val Loss: 0.0812 Accuracy: 0.9819
# Epoch 200 | Train Loss: 0.0747 Accuracy: 0.9850 | Val Loss: 0.0756 Accuracy: 0.9837
# Epoch 210 | Train Loss: 0.0696 Accuracy: 0.9859 | Val Loss: 0.0705 Accuracy: 0.9837
# Epoch 220 | Train Loss: 0.0651 Accuracy: 0.9864 | Val Loss: 0.0660 Accuracy: 0.9846
# Epoch 230 | Train Loss: 0.0611 Accuracy: 0.9868 | Val Loss: 0.0618 Accuracy: 0.9855
# Epoch 240 | Train Loss: 0.0574 Accuracy: 0.9873 | Val Loss: 0.0580 Accuracy: 0.9864
# Epoch 250 | Train Loss: 0.0541 Accuracy: 0.9878 | Val Loss: 0.0546 Accuracy: 0.9891
# Epoch 260 | Train Loss: 0.0512 Accuracy: 0.9892 | Val Loss: 0.0516 Accuracy: 0.9891
# Epoch 270 | Train Loss: 0.0486 Accuracy: 0.9892 | Val Loss: 0.0488 Accuracy: 0.9891
# Epoch 280 | Train Loss: 0.0462 Accuracy: 0.9898 | Val Loss: 0.0462 Accuracy: 0.9891
# Epoch 290 | Train Loss: 0.0440 Accuracy: 0.9910 | Val Loss: 0.0438 Accuracy: 0.9900
# Epoch 300 | Train Loss: 0.0419 Accuracy: 0.9917 | Val Loss: 0.0415 Accuracy: 0.9910
# Epoch 310 | Train Loss: 0.0400 Accuracy: 0.9919 | Val Loss: 0.0395 Accuracy: 0.9928
# Epoch 320 | Train Loss: 0.0382 Accuracy: 0.9919 | Val Loss: 0.0375 Accuracy: 0.9928
# Epoch 330 | Train Loss: 0.0363 Accuracy: 0.9924 | Val Loss: 0.0358 Accuracy: 0.9928
# EarlyStopping counter: 1 out of 10
# Epoch 340 | Train Loss: 0.0346 Accuracy: 0.9922 | Val Loss: 0.0338 Accuracy: 0.9928
# EarlyStopping counter: 1 out of 10
# Epoch 350 | Train Loss: 0.0331 Accuracy: 0.9924 | Val Loss: 0.0320 Accuracy: 0.9928
# Epoch 360 | Train Loss: 0.0316 Accuracy: 0.9933 | Val Loss: 0.0306 Accuracy: 0.9928
# EarlyStopping counter: 1 out of 10
# Epoch 370 | Train Loss: 0.0302 Accuracy: 0.9938 | Val Loss: 0.0290 Accuracy: 0.9928
# EarlyStopping counter: 1 out of 10
# Epoch 380 | Train Loss: 0.0289 Accuracy: 0.9940 | Val Loss: 0.0276 Accuracy: 0.9937
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 390 | Train Loss: 0.0277 Accuracy: 0.9940 | Val Loss: 0.0263 Accuracy: 0.9937
# EarlyStopping counter: 1 out of 10
# Epoch 400 | Train Loss: 0.0266 Accuracy: 0.9942 | Val Loss: 0.0250 Accuracy: 0.9937
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 410 | Train Loss: 0.0255 Accuracy: 0.9942 | Val Loss: 0.0239 Accuracy: 0.9937
# EarlyStopping counter: 1 out of 10
# Epoch 420 | Train Loss: 0.0245 Accuracy: 0.9945 | Val Loss: 0.0230 Accuracy: 0.9964
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 430 | Train Loss: 0.0235 Accuracy: 0.9949 | Val Loss: 0.0217 Accuracy: 0.9964
# Epoch 440 | Train Loss: 0.0225 Accuracy: 0.9947 | Val Loss: 0.0208 Accuracy: 0.9964
# Epoch 450 | Train Loss: 0.0216 Accuracy: 0.9949 | Val Loss: 0.0198 Accuracy: 0.9964
# Epoch 460 | Train Loss: 0.0209 Accuracy: 0.9947 | Val Loss: 0.0192 Accuracy: 0.9964
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 470 | Train Loss: 0.0201 Accuracy: 0.9952 | Val Loss: 0.0181 Accuracy: 0.9964
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 480 | Train Loss: 0.0193 Accuracy: 0.9954 | Val Loss: 0.0174 Accuracy: 0.9964
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 490 | Train Loss: 0.0186 Accuracy: 0.9954 | Val Loss: 0.0168 Accuracy: 0.9964
# EarlyStopping counter: 2 out of 10
# Epoch 500 | Train Loss: 0.0179 Accuracy: 0.9956 | Val Loss: 0.0160 Accuracy: 0.9964
# Epoch 510 | Train Loss: 0.0172 Accuracy: 0.9956 | Val Loss: 0.0152 Accuracy: 0.9964
# EarlyStopping counter: 1 out of 10
# Epoch 520 | Train Loss: 0.0165 Accuracy: 0.9956 | Val Loss: 0.0146 Accuracy: 0.9964
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 530 | Train Loss: 0.0159 Accuracy: 0.9956 | Val Loss: 0.0140 Accuracy: 0.9964
# EarlyStopping counter: 1 out of 10
# Epoch 540 | Train Loss: 0.0154 Accuracy: 0.9961 | Val Loss: 0.0135 Accuracy: 0.9964
# EarlyStopping counter: 1 out of 10
# Epoch 550 | Train Loss: 0.0148 Accuracy: 0.9961 | Val Loss: 0.0129 Accuracy: 0.9964
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 560 | Train Loss: 0.0142 Accuracy: 0.9963 | Val Loss: 0.0123 Accuracy: 0.9964
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 570 | Train Loss: 0.0137 Accuracy: 0.9965 | Val Loss: 0.0117 Accuracy: 0.9964
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 580 | Train Loss: 0.0132 Accuracy: 0.9970 | Val Loss: 0.0112 Accuracy: 0.9964
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 590 | Train Loss: 0.0127 Accuracy: 0.9970 | Val Loss: 0.0107 Accuracy: 0.9973
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 600 | Train Loss: 0.0121 Accuracy: 0.9970 | Val Loss: 0.0100 Accuracy: 0.9982
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 610 | Train Loss: 0.0116 Accuracy: 0.9972 | Val Loss: 0.0095 Accuracy: 0.9991
# Epoch 620 | Train Loss: 0.0111 Accuracy: 0.9977 | Val Loss: 0.0090 Accuracy: 0.9991
# Epoch 630 | Train Loss: 0.0107 Accuracy: 0.9977 | Val Loss: 0.0086 Accuracy: 1.0000
# Epoch 640 | Train Loss: 0.0102 Accuracy: 0.9977 | Val Loss: 0.0082 Accuracy: 1.0000
# Epoch 650 | Train Loss: 0.0098 Accuracy: 0.9982 | Val Loss: 0.0078 Accuracy: 1.0000
# EarlyStopping counter: 1 out of 10
# Epoch 660 | Train Loss: 0.0094 Accuracy: 0.9982 | Val Loss: 0.0075 Accuracy: 1.0000
# Epoch 670 | Train Loss: 0.0090 Accuracy: 0.9984 | Val Loss: 0.0071 Accuracy: 1.0000
# Epoch 680 | Train Loss: 0.0086 Accuracy: 0.9984 | Val Loss: 0.0067 Accuracy: 1.0000
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 690 | Train Loss: 0.0082 Accuracy: 0.9984 | Val Loss: 0.0064 Accuracy: 1.0000
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Epoch 700 | Train Loss: 0.0079 Accuracy: 0.9984 | Val Loss: 0.0061 Accuracy: 1.0000
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Epoch 710 | Train Loss: 0.0075 Accuracy: 0.9984 | Val Loss: 0.0058 Accuracy: 1.0000
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Epoch 720 | Train Loss: 0.0071 Accuracy: 0.9984 | Val Loss: 0.0055 Accuracy: 1.0000
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Epoch 730 | Train Loss: 0.0067 Accuracy: 0.9984 | Val Loss: 0.0053 Accuracy: 1.0000
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Epoch 740 | Train Loss: 0.0061 Accuracy: 0.9984 | Val Loss: 0.0051 Accuracy: 0.9991
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Epoch 750 | Train Loss: 0.0057 Accuracy: 0.9984 | Val Loss: 0.0046 Accuracy: 1.0000
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 760 | Train Loss: 0.0053 Accuracy: 0.9991 | Val Loss: 0.0047 Accuracy: 1.0000
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 770 | Train Loss: 0.0050 Accuracy: 0.9993 | Val Loss: 0.0043 Accuracy: 0.9991
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 780 | Train Loss: 0.0047 Accuracy: 0.9991 | Val Loss: 0.0039 Accuracy: 1.0000
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 790 | Train Loss: 0.0044 Accuracy: 0.9998 | Val Loss: 0.0039 Accuracy: 0.9991
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 800 | Train Loss: 0.0042 Accuracy: 0.9995 | Val Loss: 0.0037 Accuracy: 1.0000
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 810 | Train Loss: 0.0040 Accuracy: 0.9995 | Val Loss: 0.0035 Accuracy: 1.0000
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 820 | Train Loss: 0.0038 Accuracy: 0.9995 | Val Loss: 0.0034 Accuracy: 1.0000
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Epoch 830 | Train Loss: 0.0036 Accuracy: 0.9998 | Val Loss: 0.0033 Accuracy: 0.9991
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 840 | Train Loss: 0.0034 Accuracy: 0.9995 | Val Loss: 0.0032 Accuracy: 0.9991
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 850 | Train Loss: 0.0032 Accuracy: 0.9998 | Val Loss: 0.0030 Accuracy: 0.9991
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 860 | Train Loss: 0.0031 Accuracy: 1.0000 | Val Loss: 0.0030 Accuracy: 0.9991
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 870 | Train Loss: 0.0029 Accuracy: 1.0000 | Val Loss: 0.0029 Accuracy: 0.9991
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# Epoch 880 | Train Loss: 0.0028 Accuracy: 1.0000 | Val Loss: 0.0028 Accuracy: 0.9991
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Epoch 890 | Train Loss: 0.0027 Accuracy: 1.0000 | Val Loss: 0.0028 Accuracy: 1.0000
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# Epoch 900 | Train Loss: 0.0025 Accuracy: 1.0000 | Val Loss: 0.0025 Accuracy: 0.9991
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping

# %%
epochs = len(loss_list)

# %% [markdown]
# 绘制Accuracy图

# %%
# %matplotlib inline

# %%
# plt.rcParams['font.sans-serif'] = ['Arial']  # 如果要显示中文字体,则在此处设为：SimHei
# plt.rcParams['axes.unicode_minus'] = False  # 显示负号

plt.figure(figsize=(10, 5))
plt.grid(True, linestyle='--',which='both')  # 设置背景网格线为虚线

ax = plt.gca()
ax.spines['top'].set_visible(False)  # 去掉上边框
ax.spines['right'].set_visible(False)  # 去掉右边框
#ax.set_facecolor("white")

plt.plot(range(epochs), loss_list, label='Train Loss',c='r')
plt.plot(range(epochs), val_loss_list, label='Val Loss',c='b')

plt.title('Loss')
plt.xlabel('Train Epoch')
plt.ylabel('Loss')
plt.legend(loc=1) #第二象项，也就是左上角。 loc可以为1,2,3,4

# leg = plt.gca().get_legend()
# ltext = leg.get_texts()
# plt.setp(ltext, fontsize=12, fontweight='bold')  # 设置图例字体的大小和粗细
plt.savefig('Loss.png')
plt.show();

# %% [markdown]
# 绘制acc图

# %%
plt.figure(figsize=(10, 5))
plt.grid(True, linestyle='--',which='both')  # 设置背景网格线为虚线

plt.plot(range(epochs), acc, label='Train Accuracy',c='r')
plt.plot(range(epochs), val_acc, label='Val Accuracy',c='b')
plt.title('Train & Val Accuracy')
plt.xlabel('Train Epoch')
plt.ylabel('Accuracy')
plt.savefig('Accuracy.png')
plt.legend(loc=4) #第二象项，也就是左上角。 loc可以为1,2,3,4
plt.show();

# %%
#读取
my_model = torch.load(f'model/model_checkpoint_{sample}.pth')
pred = model(edge_pred_graph, node_feats, edge_feats)

# %%
torch.set_printoptions(sci_mode=False)

y_pred = torch.argmax(pred[test_mask],axis=1).tolist()
y_test = edge_label[test_mask].tolist()
y_prob = F.softmax(pred[test_mask])[:,1].tolist()
# Out:
# C:\Users\tojoy\AppData\Local\Temp\ipykernel_43556\2418179127.py:5: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_prob = F.softmax(pred[test_mask])[:,1].tolist()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       505
#            1       1.00      1.00      1.00       600
#
#     accuracy                           1.00      1105
#    macro avg       1.00      1.00      1.00      1105
# weighted avg       1.00      1.00      1.00      1105

# %%
# 二分类评价指标
def evaluate(result, test_y, probas, name = 'mymodel'):
    # 1-1 评估指标
    acc = np.mean([result[i] == test_y[i] for i in range(len(result))])
    precision = metrics.precision_score(test_y,result)
    recall = metrics.recall_score(test_y,result)
    f1 = metrics.f1_score(test_y,result)
    #spe = specificity_loss_func(test_y, result)
    print("准确率:",acc.round(4))
    print("精确率:",precision.round(4))
    print("召回率:",recall.round(4))
    
    print("F1:",f1.round(4))

    # 1-2.混淆矩阵
    confusion_mat = confusion_matrix(test_y, result)
    
    tn, fp, fn, tp = confusion_mat.ravel()
    
    # 计算敏感性和特异性
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    print("特异度:",round(specificity,4))
    print("敏感度:",round(sensitivity,4))

    disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat)
    disp.plot(
        include_values=True,            
        cmap=plt.cm.Blues,
        ax=None,                        
        xticks_rotation="horizontal",   
        values_format=".2f"
    )
    plt.title(f"{name} confusion matrix")
    plt.grid(False)
    plt.show();

    # ROC曲线
    roc = metrics.roc_auc_score(test_y,probas)
    print("AUC值:",roc.round(4))
    fpr,tpr,thresholds=metrics.roc_curve(test_y,probas)
    plt.plot(fpr,tpr, label=f"{name} ROC curve (area={round(roc,2)})")
    plt.plot([0,1],[0,1],linestyle='dashed')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"{name} ROC")
    plt.legend(loc='lower right')
    plt.grid(linestyle='-.')  
    plt.grid(True)
    plt.show();
    
    #敏感性特异性曲线
    plt.plot(thresholds, 1-fpr, label='specificity')
    plt.plot(thresholds, tpr, label='sensitivity')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('Classification Proportion')
    plt.xlabel('Cutoff')
    plt.legend()
    plt.show()    
    
    # PR曲线
    
    precision,recall,thresholds=metrics.precision_recall_curve(test_y,probas)
    plt.plot(recall,precision,color='y',label=name)
    plt.title(f'{name} Precision-recall curve')
    plt.legend(loc='lower left')
    plt.plot([1,0],[0,1],'r--')
    plt.xlim([-0.05,1.05])
    plt.ylim([-0.05,1.05])
    plt.ylabel('Precision')
    plt.xlabel('Recall')
    plt.grid(linestyle='-.')  
    plt.grid(True)
    plt.show()
    
    return

# %%
evaluate(y_pred, y_test, y_prob, name = 'model')
# Out:
# 准确率: 0.9991
# 精确率: 1.0
# 召回率: 0.9983
# F1: 0.9992
# 特异度: 1.0
# 敏感度: 0.9983
# AUC值: 1.0
